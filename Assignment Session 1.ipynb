# %% [markdown]
# # Stats ML Homework

# %% [markdown]
# #### Chap 2 Exercise 2

# %% [markdown]
# Explain whether each scenario is a classification or regression problem,
# and indicate whether we are most interested in inference or prediction. Finally, provide n and p.

# %% [markdown]
# *(a) We collect a set of data on the top 500 firms in the US. For each
# firm we record profit, number of employees, industry and the
# CEO salary. We are interested in understanding which factors
# affect CEO salary.*
#
# This is a classification problem, we are most interested in inference. n = 500;  p = 4

# %% [markdown]
# *(b) We are considering launching a new product and wish to know
# whether it will be a success or a failure. We collect data on 20
# similar products that were previously launched. For each product we have recorded whether it was a success or failure, price
# charged for the product, marketing budget, competition price,
# and ten other variables.*
#
# This is a classification problem, we are most interested in prediction. n = 20; p = 14

# %% [markdown]
# *(c) We are interest in predicting the % change in the USD/Euro
# exchange rate in relation to the weekly changes in the world
# stock markets. Hence we collect weekly data for all of 2012. For
# each week we record the % change in the USD/Euro, the %
# change in the US market, the % change in the British market,
# and the % change in the German market.*
#
# This is a regression problem, we are most interested in prediction. n = 52; p = 4

# %% [markdown]
# #### Chap 2 Exercise 10

# %% [markdown]
# *(a) To begin, load in the Boston data set. The Boston data set is
# part of the MASS library in R.*

# %%
library(MASS)

# %% [markdown]
# *Now the data set is contained in the object Boston.*

# %% [markdown]
# Boston

# %% [markdown]
# *Read about the data set:*

# %%
?Boston

# %% [markdown]
# *Make some pairwise scatterplots of the predictors (columns) in
# this data set. Describe your findings.*

# %%
pairs(Boston)
# In these scatterplots we can perceive that every predictor has some other predictors related, 
# as it is the case of the predictor black and age, which represents the age of black people in the town of Boston
# Out:
# plot without title

# %% [markdown]
# *Are any of the predictors associated with per capita crime rate?
# If so, explain the relationship.*
#
# Yes, the distance to employment center has an inverse relationship with the crime rate as we can see in the scatter plot. Also, the age has a direct relationship and median value of owner occupied has an inverse relationship.

# %% [markdown]
# *Do any of the suburbs of Boston appear to have particularly
# high crime rates? Tax rates? Pupil-teacher ratios? Comment on
# the range of each predictor*
#
# According to the basic stats there is an outlier in crime rates. On the contrary, the other predictors seem to be almost normally distributed

# %%
 summary(Boston)
# Out:
#       crim                zn             indus            chas
#  Min.   : 0.00632   Min.   :  0.00   Min.   : 0.46   Min.   :0.00000
#  1st Qu.: 0.08204   1st Qu.:  0.00   1st Qu.: 5.19   1st Qu.:0.00000
#  Median : 0.25651   Median :  0.00   Median : 9.69   Median :0.00000
#  Mean   : 3.61352   Mean   : 11.36   Mean   :11.14   Mean   :0.06917
#  3rd Qu.: 3.67708   3rd Qu.: 12.50   3rd Qu.:18.10   3rd Qu.:0.00000
#  Max.   :88.97620   Max.   :100.00   Max.   :27.74   Max.   :1.00000
#       nox               rm             age              dis
#  Min.   :0.3850   Min.   :3.561   Min.   :  2.90   Min.   : 1.130
#  1st Qu.:0.4490   1st Qu.:5.886   1st Qu.: 45.02   1st Qu.: 2.100
#  Median :0.5380   Median :6.208   Median : 77.50   Median : 3.207
#  Mean   :0.5547   Mean   :6.285   Mean   : 68.57   Mean   : 3.795
#  3rd Qu.:0.6240   3rd Qu.:6.623   3rd Qu.: 94.08   3rd Qu.: 5.188
#  Max.   :0.8710   Max.   :8.780   Max.   :100.00   Max.   :12.127
# ...

# %% [markdown]
# *How many of the suburbs in this data set bound the Charles
# river?*

# %%
Boston_filtered <- Boston[ Boston$chas == 1 , ]
nrow(Boston_filtered)
# Out:
# [1] 35

# %% [markdown]
# *What is the median pupil-teacher ratio among the towns in this
# data set?*

# %%
median(Boston$ptratio)
# Out:
# [1] 19.05

# %% [markdown]
# *Which suburb of Boston has lowest median value of owneroccupied homes? What are the values of the other predictors
# for that suburb, and how do those values compare to the overall
# ranges for those predictors? Comment on your findings.*

# %%
Boston[Boston$medv == min(Boston$medv),]
# Out:
#     crim    zn indus chas nox   rm    age dis    rad tax ptratio black  lstat
# 399 38.3518 0  18.1  0    0.693 5.453 100 1.4896 24  666 20.2    396.90 30.59
# 406 67.9208 0  18.1  0    0.693 5.683 100 1.4254 24  666 20.2    384.97 22.98
#     medv
# 399 5
# 406 5

# %% [markdown]
# *In this data set, how many of the suburbs average more than
# seven rooms per dwelling? More than eight rooms per dwelling?
# Comment on the suburbs that average more than eight rooms
# per dwelling*

# %%
nrow(Boston[Boston$rm >7, ])
# Out:
# [1] 64

# %%
nrow(Boston[Boston$rm >8, ])
# Out:
# [1] 13

# %%
Boston[Boston$rm >8, ]
# Out:
#     crim    zn indus chas nox    rm    age  dis    rad tax ptratio black  lstat
# 98  0.12083  0  2.89 0    0.4450 8.069 76.0 3.4952  2  276 18.0    396.90 4.21
# 164 1.51902  0 19.58 1    0.6050 8.375 93.9 2.1620  5  403 14.7    388.45 3.32
# 205 0.02009 95  2.68 0    0.4161 8.034 31.9 5.1180  4  224 14.7    390.55 2.88
# 225 0.31533  0  6.20 0    0.5040 8.266 78.3 2.8944  8  307 17.4    385.05 4.14
# 226 0.52693  0  6.20 0    0.5040 8.725 83.0 2.8944  8  307 17.4    382.00 4.63
# 227 0.38214  0  6.20 0    0.5040 8.040 86.5 3.2157  8  307 17.4    387.38 3.13
# 233 0.57529  0  6.20 0    0.5070 8.337 73.3 3.8384  8  307 17.4    385.91 2.47
# 234 0.33147  0  6.20 0    0.5070 8.247 70.4 3.6519  8  307 17.4    378.95 3.95
# 254 0.36894 22  5.86 0    0.4310 8.259  8.4 8.9067  7  330 19.1    396.90 3.54
# 258 0.61154 20  3.97 0    0.6470 8.704 86.9 1.8010  5  264 13.0    389.70 5.12
# 263 0.52014 20  3.97 0    0.6470 8.398 91.5 2.2885  5  264 13.0    386.86 5.91
# ...

# %% [markdown]
# #### Chapter 3 Exercise 3

# %% [markdown]
# *Suppose we have a data set with five predictors, X1 = GPA, X2 = IQ,
# X3 = Gender (1 for Female and 0 for Male), X4 = Interaction between
# GPA and IQ, and X5 = Interaction between GPA and Gender. The
# response is starting salary after graduation (in thousands of dollars).
# Suppose we use least squares to fit the model, and get βˆ0 = 50, βˆ1 =
# 20, βˆ2 = 0.07, βˆ3 = 35, βˆ4 = 0.01, βˆ5 = −10.*
#
# (a) Which answer is correct, and why?
#
# i. For a fixed value of IQ and GPA, males earn more on average
# than females.
#
# ii. For a fixed value of IQ and GPA, females earn more on
# average than males.
#
# iii. For a fixed value of IQ and GPA, males earn more on average
# than females provided that the GPA is high enough.
#
# iv. For a fixed value of IQ and GPA, females earn more on
# average than males provided that the GPA is high enough.
#
# (b) Predict the salary of a female with IQ of 110 and a GPA of 4.0.
#
# (c) True or false: Since the coefficient for the GPA/IQ interaction*
# term is very small, there is very little evidence of an interaction
# effect. Justify your answer.

# %% [markdown]
# a)  For a fixed value of IQ and GPA, females earn more on average than males. This is the correct answer because for any value of GPA we will be multiplying the B3 to 1 for females and to 0 for males. Therefore, in case of male we would be losing 25k.

# %%
b <- 50 + 20*4.0 + 0.07*110+ 35*1 + 0.01*4.0*110 - 10*1  
b
# Out:
# [1] 167.1

# %% [markdown]
# c) False. The interaction effect is not measured on the value of the coefficient but rather on the difference between making the prediction with vs without the interaction

# %% [markdown]
# #### Chapter 3 Exercise 10

# %%
install.packages('ISLR', , repos = "http://cran.us.r-project.org");
# Out:
#   There is a binary version available but the source version is later:
#      binary source needs_compilation
# ISLR    1.2    1.4             FALSE
# installing the source package 'ISLR'

# %%
library("ISLR")

# %%
carseats_dt <- Carseats
lm.fit=lm(Sales∼.+Price +Urban:US ,data=carseats_dt )
summary(lm.fit)
# Out:
# Call:
# lm(formula = Sales ~ . + Price + Urban:US, data = carseats_dt)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.8936 -0.6935  0.0043  0.6518  3.3656
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)      5.7628474  0.6054762   9.518   <2e-16 ***
# CompPrice        0.0933633  0.0041527  22.482   <2e-16 ***
# Income           0.0159686  0.0018441   8.659   <2e-16 ***
# Advertising      0.1230410  0.0111005  11.084   <2e-16 ***
# Population       0.0002165  0.0003697   0.586   0.5584
# Price           -0.0956705  0.0026724 -35.799   <2e-16 ***
# ShelveLocGood    4.8740674  0.1534978  31.753   <2e-16 ***
# ShelveLocMedium  1.9661635  0.1259765  15.607   <2e-16 ***
# Age             -0.0462265  0.0031770 -14.550   <2e-16 ***
# Education       -0.0203104  0.0196853  -1.032   0.3028
# UrbanYes        -0.1124480  0.1837721  -0.612   0.5410
# USYes           -0.4463843  0.2202778  -2.026   0.0434 *
# ...
